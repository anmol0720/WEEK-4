# %% [markdown]
# # 1st DATASET

# %%
df=read.csv("../input/College.csv")
df
# Out:
#     X                                       Private Apps  Accept Enroll
# 1   Abilene Christian University            Yes      1660  1232   721
# 2   Adelphi University                      Yes      2186  1924   512
# 3   Adrian College                          Yes      1428  1097   336
# 4   Agnes Scott College                     Yes       417   349   137
# 5   Alaska Pacific University               Yes       193   146    55
# 6   Albertson College                       Yes       587   479   158
# 7   Albertus Magnus College                 Yes       353   340   103
# 8   Albion College                          Yes      1899  1720   489
# 9   Albright College                        Yes      1038   839   227
# 10  Alderson-Broaddus College               Yes       582   498   172
# 11  Alfred University                       Yes      1732  1425   472
# 12  Allegheny College                       Yes      2652  1900   484
# ...

# %%
df=na.omit(df)

# %%
summary(df)
# Out:
#                             X       Private        Apps           Accept
#  Abilene Christian University:  1   No :212   Min.   :   81   Min.   :   72
#  Adelphi University          :  1   Yes:565   1st Qu.:  776   1st Qu.:  604
#  Adrian College              :  1             Median : 1558   Median : 1110
#  Agnes Scott College         :  1             Mean   : 3002   Mean   : 2019
#  Alaska Pacific University   :  1             3rd Qu.: 3624   3rd Qu.: 2424
#  Albertson College           :  1             Max.   :48094   Max.   :26330
#  (Other)                     :771
#      Enroll       Top10perc       Top25perc      F.Undergrad
#  Min.   :  35   Min.   : 1.00   Min.   :  9.0   Min.   :  139
#  1st Qu.: 242   1st Qu.:15.00   1st Qu.: 41.0   1st Qu.:  992
#  Median : 434   Median :23.00   Median : 54.0   Median : 1707
#  Mean   : 780   Mean   :27.56   Mean   : 55.8   Mean   : 3700
#  3rd Qu.: 902   3rd Qu.:35.00   3rd Qu.: 69.0   3rd Qu.: 4005
# ...

# %%
attach(df)
plot(Private,Outstate,horizontal=T,col=2,xlab='Private',ylab='Outstate',main='Outstate vs Private')

# %%
pairs(df[,1:10])

# %%
attach(df)
# Out:
# The following objects are masked from df (pos = 3):
#
#     Accept, Apps, Books, Enroll, Expend, F.Undergrad, Grad.Rate,
#     Outstate, P.Undergrad, perc.alumni, Personal, PhD, Private,
#     Room.Board, S.F.Ratio, Terminal, Top10perc, Top25perc, X

# %%
par(mfrow=c(2,2))
hist(Accept,col=2)
hist(Enroll,col=3)
hist(Top25perc,col=4)
hist(Room.Board,col=7)

# %%
elite=rep('No',nrow(df))
elite['Top10perc'>50]='Yes'
elite=as.factor(elite)
df=data.frame(df,elite)
summary(elite)
# Out:
# Yes
# 777

# %%
plot(elite,Outstate,horizontal=T,xlab='Elite',ylab='Outstate',col=3,main='Outstate vs Elite')

# %% [markdown]
# # 2nd DataSet

# %%
df1=read.csv("../input/Auto.csv",header=T,na.string='?')

# %%
df1
# Out:
#     mpg cylinders displacement horsepower weight acceleration year origin
# 1   18  8         307          130        3504   12.0         70   1
# 2   15  8         350          165        3693   11.5         70   1
# 3   18  8         318          150        3436   11.0         70   1
# 4   16  8         304          150        3433   12.0         70   1
# 5   17  8         302          140        3449   10.5         70   1
# 6   15  8         429          198        4341   10.0         70   1
# 7   14  8         454          220        4354    9.0         70   1
# 8   14  8         440          215        4312    8.5         70   1
# 9   14  8         455          225        4425   10.0         70   1
# 10  15  8         390          190        3850    8.5         70   1
# 11  15  8         383          170        3563   10.0         70   1
# 12  14  8         340          160        3609    8.0         70   1
# 13  15  8         400          150        3761    9.5         70   1
# ...

# %%
attach(df1)

# %%
df1=na.omit(df1)

# %%
range(horsepower)
# Out:
# [1] NA NA

# %%
summary(df1)
# Out:
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1613
#  1st Qu.:17.00   1st Qu.:4.000   1st Qu.:105.0   1st Qu.: 75.0   1st Qu.:2225
#  Median :22.75   Median :4.000   Median :151.0   Median : 93.5   Median :2804
#  Mean   :23.45   Mean   :5.472   Mean   :194.4   Mean   :104.5   Mean   :2978
#  3rd Qu.:29.00   3rd Qu.:8.000   3rd Qu.:275.8   3rd Qu.:126.0   3rd Qu.:3615
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   Max.   :230.0   Max.   :5140
#
#   acceleration        year           origin                      name
#  Min.   : 8.00   Min.   :70.00   Min.   :1.000   amc matador       :  5
#  1st Qu.:13.78   1st Qu.:73.00   1st Qu.:1.000   ford pinto        :  5
#  Median :15.50   Median :76.00   Median :1.000   toyota corolla    :  5
#  Mean   :15.54   Mean   :75.98   Mean   :1.577   amc gremlin       :  4
# ...

# %%
#Extracting the Quantative Data
x=df1[,1:8]

# %%
summary(x)
# Out:
#       mpg          cylinders      displacement     horsepower        weight
#  Min.   : 9.00   Min.   :3.000   Min.   : 68.0   Min.   : 46.0   Min.   :1613
#  1st Qu.:17.00   1st Qu.:4.000   1st Qu.:105.0   1st Qu.: 75.0   1st Qu.:2225
#  Median :22.75   Median :4.000   Median :151.0   Median : 93.5   Median :2804
#  Mean   :23.45   Mean   :5.472   Mean   :194.4   Mean   :104.5   Mean   :2978
#  3rd Qu.:29.00   3rd Qu.:8.000   3rd Qu.:275.8   3rd Qu.:126.0   3rd Qu.:3615
#  Max.   :46.60   Max.   :8.000   Max.   :455.0   Max.   :230.0   Max.   :5140
#   acceleration        year           origin
#  Min.   : 8.00   Min.   :70.00   Min.   :1.000
#  1st Qu.:13.78   1st Qu.:73.00   1st Qu.:1.000
#  Median :15.50   Median :76.00   Median :1.000
#  Mean   :15.54   Mean   :75.98   Mean   :1.577
#  3rd Qu.:17.02   3rd Qu.:79.00   3rd Qu.:2.000
#  Max.   :24.80   Max.   :82.00   Max.   :3.000

# %%
y=df1[10:85,]
summary(y)
# Out:
#       mpg          cylinders      displacement     horsepower
#  Min.   : 9.00   Min.   :3.000   Min.   : 70.0   Min.   : 46.00
#  1st Qu.:14.00   1st Qu.:4.000   1st Qu.:112.2   1st Qu.: 87.75
#  Median :19.00   Median :6.000   Median :212.5   Median : 98.50
#  Mean   :19.46   Mean   :5.882   Mean   :224.2   Mean   :120.05
#  3rd Qu.:25.00   3rd Qu.:8.000   3rd Qu.:342.5   3rd Qu.:156.25
#  Max.   :35.00   Max.   :8.000   Max.   :455.0   Max.   :225.00
#
#      weight      acceleration        year           origin
#  Min.   :1613   Min.   : 8.00   Min.   :70.00   Min.   :1.000
#  1st Qu.:2262   1st Qu.:13.00   1st Qu.:70.00   1st Qu.:1.000
#  Median :2948   Median :14.50   Median :71.00   Median :1.000
#  Mean   :3151   Mean   :14.77   Mean   :71.13   Mean   :1.474
#  3rd Qu.:4107   3rd Qu.:16.12   3rd Qu.:72.00   3rd Qu.:2.000
#  Max.   :5140   Max.   :23.50   Max.   :73.00   Max.   :3.000
#
#                  name
#  amc gremlin       : 2
#  chevrolet impala  : 2
# ...

# %%
pairs(df1)

# %% [markdown]
# From the above plot we get to know that the mpg has negetive relation with displacement,horsepower and weight and is positively related with acceleration.

# %% [markdown]
# Yes other variables will be usefull in predicting gas mileage(mpg) as it can be easily related to displacement,horsepower,weight and acceleration but other variables will not be useful in predicting mpg as they are not properly related.
#
#     AS SHOWN BY SCATTER PLOT ABOVE

# %% [markdown]
# # 3rd DATASET

# %%
df2=read.csv("../input/Housing.csv",header=T,na.string='?')
df2
# Out:
#       id         date            price   bedrooms bathrooms sqft_living
# 1     7129300520 20141013T000000  221900 3        1.00      1180
# 2     6414100192 20141209T000000  538000 3        2.25      2570
# 3     5631500400 20150225T000000  180000 2        1.00       770
# 4     2487200875 20141209T000000  604000 4        3.00      1960
# 5     1954400510 20150218T000000  510000 3        2.00      1680
# 6     7237550310 20140512T000000 1225000 4        4.50      5420
# 7     1321400060 20140627T000000  257500 3        2.25      1715
# 8     2008000270 20150115T000000  291850 3        1.50      1060
# 9     2414600126 20150415T000000  229500 3        1.00      1780
# 10    3793500160 20150312T000000  323000 3        2.50      1890
# 11    1736800520 20150403T000000  662500 3        2.50      3560
# 12    9212900260 20140527T000000  468000 2        1.00      1160
# 13     114101516 20140528T000000  310000 3        1.00      1430
# ...

# %%
attach(df2)

# %%
dim(df2)
# Out:
# [1] 21613    21

# %% [markdown]
# It reprents 21613 Rows i.e., Datas and 21 Columns i.e., Different Independent Variable

# %%
par(mfrow=c(2,2))
plot(price,sqft_living,col=20)
plot(price,sqft_lot,col=21)
plot(price,sqft_above,col=22)
plot(price,sqft_basement,col=23)

# %% [markdown]
# From the above pair plots we can determine that the price of the house can be predicted more accuretly by sqft_living and sqft_above , But not by sqft_lot and sqft_above
